# %% [markdown]
# <a href="https://colab.research.google.com/github/yashar1908/Text-translation-using-Mistral-7B/blob/main/LLM_for_Translation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ctransformers[cuda]
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 57.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.0/302.0 kB 38.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 417.9/417.9 MB 2.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 867.7/867.7 kB 72.8 MB/s eta 0:00:00
# ...

# %%
from ctransformers import AutoModelForCausalLM

# %%
llm = AutoModelForCausalLM.from_pretrained("TheBloke/Mistral-7B-Instruct-v0.1-GGUF",
model_file="mistral-7b-instruct-v0.1.Q4_K_M.gguf",
model_type = "mistral", gpu_layers = 50)
# Out:
# Fetching 1 files:   0%|          | 0/1 [00:00<?, ?it/s]
# (…)a64a14aea61a4c468bbbf9f258a8/config.json:   0%|          | 0.00/31.0 [00:00<?, ?B/s]
# Fetching 1 files:   0%|          | 0/1 [00:00<?, ?it/s]
# mistral-7b-instruct-v0.1.Q4_K_M.gguf:   0%|          | 0.00/4.37G [00:00<?, ?B/s]

# %%
def colab_print(text, max_width = 120):
  words = text.split()
  line = ""
  for word in words:
    if len(line) + len(word) + 1 > max_width:
      print(line)
      line = ""
    line += word + " "
  print (line)

# %%
text = input("Enter what you want to translate: ")
# Out:
# Enter what you want to translate: Thanks for viewing my project!

# %%
colab_print(llm(f'''Translate this text from English to French:
"{text}"''',
                max_new_tokens=2048, temperature=0.9, top_k=55, top_p=0.93,
                repetition_penalty=1.2))
# Out:
# Merci d'avoir regardé mon projet !
